# %%
import numpy as np
import matplotlib.pyplot as plt

def leastSquares(A, b):
    import numpy.linalg as npl
    return npl.lstsq(A, b, rcond=None)[0]

# %%
"""
Load csv File.
"""
file_path = "IRIS.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
print((df['species'] == 'Iris-setosa').sum())
print((df['species'] == 'Iris-versicolor').sum())
print((df['species'] == 'Iris-virginica').sum())
# Out:
# 50
# 50
# 50

# %%
setosa = [row for row in df]
setosa = np.array(df.loc[(df['species'] == 'Iris-setosa'), ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']])
versicolor = np.array(df.loc[(df['species'] == 'Iris-versicolor'), ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']])
virginica = np.array(df.loc[(df['species'] == 'Iris-virginica'), ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']])
setosa
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
A = np.zeros((150,4))
A[0:50, :] = setosa
A[50:100, :] = versicolor
A[100:150, :] = virginica
print(len(A))
A[:5]
# Out:
# 150
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
A = np.hstack([np.ones([150,1]), A])
A[:5]
# Out:
# array([[1. , 5.1, 3.5, 1.4, 0.2],
#        [1. , 4.9, 3. , 1.4, 0.2],
#        [1. , 4.7, 3.2, 1.3, 0.2],
#        [1. , 4.6, 3.1, 1.5, 0.2],
#        [1. , 5. , 3.6, 1.4, 0.2]])

# %%
# virginica
y = np.zeros((150,1))
y[0:100] = -1
y[100:150] = 1

# %%
x = leastSquares(A, y)
x
# Out:
# array([[-2.37089293],
#        [-0.08819682],
#        [ 0.39646511],
#        [ 0.00848001],
#        [ 1.09308541]])

# %%
yhat = A @ x

# %%
plt.plot(range(150), yhat)

# %%
def sign(x):
    return 2.0* (x > 0) - 1.0

# %%
y == sign(yhat)
# Out:
# array([[ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
# ...

# %%
# accuracy 
sum(y == sign(yhat)) / 150
# Out:
# array([0.92666667])

# %%
# error rate
sum(y != sign(yhat)) / 150
# Out:
# array([0.07333333])

# %%
x_virginica = x

# %%
# setosa
y = np.zeros((150,1))
y[0:50] = 1
y[50:150] = -1

# %%
x_setosa = leastSquares(A, y)
x_setosa
# Out:
# array([[-0.75506092],
#        [ 0.1312861 ],
#        [ 0.48494601],
#        [-0.44552275],
#        [-0.12670283]])

# %%
# versicolor
y = np.zeros((150,1))
y[0:50] = -1
y[50:100] = 1
y[100:150] = -1

# %%
x_versicolor = leastSquares(A, y)
x_versicolor
# Out:
# array([[ 2.12595385],
#        [-0.04308928],
#        [-0.88141112],
#        [ 0.43704274],
#        [-0.96638259]])

# %%
plt.plot(range(150), A @ x_virginica, range(150), A @ x_setosa, range(150), A @ x_versicolor, )

# %%
def fhat(r):
    ysetosa = r @ x_setosa
    yversicolor = r @ x_versicolor
    yvirginica = r @ x_virginica
    outs = [ysetosa, yversicolor, yvirginica]
    if max(outs) == ysetosa:
        return 'setosa'
    elif max(outs) == yversicolor:
        return 'versicolor'
    else:
        return 'virginica'

# %%
for i in range(150):
    print(fhat(A[i,:]))
# Out:
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# setosa
# virginica
# virginica
# virginica
# versicolor
# versicolor
# versicolor
# virginica
# versicolor
# versicolor
# versicolor
# versicolor
# virginica
# versicolor
# versicolor
# virginica
# virginica
# virginica
# versicolor
# versicolor
# versicolor
# virginica
# versicolor
# versicolor
# versicolor
# versicolor
# virginica
# versicolor
# virginica
# virginica
# versicolor
# versicolor
# versicolor
# versicolor
# versicolor
# virginica
# virginica
# virginica
# versicolor
# virginica
# versicolor
# versicolor
# versicolor
# versicolor
# ...

# %%
correct = ['setosa'] * 50 + ['versicolor'] * 50 + ['virginica'] * 50
correct
# Out:
# ['setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'setosa',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
#  'versicolor',
# ...

# %%
yhat = np.array([fhat(A[i,:]) for i in range(150)])

# %%
# model error
errors = sum(yhat != np.array(correct))
errors / 150
# Out:
# np.float64(0.15333333333333332)

# %%
# model accuract
accuracy = sum(yhat == np.array(correct))
accuracy / 150
# Out:
# np.float64(0.8466666666666667)
